# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sb

# %%
data=pd.read_csv("C:\\Users\\DS1\\Downloads\\auto-mpg.csv")

# %%
data.shape
# Out:
# (398, 9)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car name      398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
data.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration  \
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.425879  2970.424623     15.568090
# std      7.815984    1.701004    104.269838   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000
#
#        model year      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
data.isna().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model year      0
# origin          0
# car name        0
# dtype: int64

# %%
data.ndim
# Out:
# 2

# %%
data.size
# Out:
# 3582

# %%
plt.hist(data["weight"])
# Out:
# (array([31., 90., 59., 54., 37., 40., 29., 34., 18.,  6.]),
#  array([1613. , 1965.7, 2318.4, 2671.1, 3023.8, 3376.5, 3729.2, 4081.9,
#         4434.6, 4787.3, 5140. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(data["weight"])
# Out:
# (array([31., 90., 59., 54., 37., 40., 29., 34., 18.,  6.]),
#  array([1613. , 1965.7, 2318.4, 2671.1, 3023.8, 3376.5, 3729.2, 4081.9,
#         4434.6, 4787.3, 5140. ]),
#  <BarContainer object of 10 artists>)

# %%
data.head(5).describe()
# Out:
#             mpg  cylinders  displacement       weight  acceleration  \
# count   5.00000        5.0      5.000000     5.000000       5.00000
# mean   16.80000        8.0    316.200000  3503.000000      11.40000
# std     1.30384        0.0     19.879638   110.006818       0.65192
# min    15.00000        8.0    302.000000  3433.000000      10.50000
# 25%    16.00000        8.0    304.000000  3436.000000      11.00000
# 50%    17.00000        8.0    307.000000  3449.000000      11.50000
# 75%    18.00000        8.0    318.000000  3504.000000      12.00000
# max    18.00000        8.0    350.000000  3693.000000      12.00000
#
#        model year  origin
# count         5.0     5.0
# mean         70.0     1.0
# std           0.0     0.0
# min          70.0     1.0
# 25%          70.0     1.0
# 50%          70.0     1.0
# 75%          70.0     1.0
# max          70.0     1.0

# %%
data["horsepower"].describe()
# Out:
# count     398
# unique     94
# top       150
# freq       22
# Name: horsepower, dtype: object

# %%
data["horsepower"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 398 entries, 0 to 397
# Series name: horsepower
# Non-Null Count  Dtype
# --------------  -----
# 398 non-null    object
# dtypes: object(1)
# memory usage: 3.2+ KB

# %%
sb.boxplot(x=data["cylinders"],y=data["acceleration"])
# Out:
# <Axes: xlabel='cylinders', ylabel='acceleration'>

# %%
sb.histplot(x=data["cylinders"],y=data["model year"])
# Out:
# <Axes: xlabel='cylinders', ylabel='model year'>

# %%
sb.violinplot(x=data["cylinders"],y=data["model year"])
# Out:
# <Axes: xlabel='cylinders', ylabel='model year'>

# %%
sb.scatterplot(x=data["cylinders"],y=data["model year"])
# Out:
# <Axes: xlabel='cylinders', ylabel='model year'>

# %%
data["acceleration"]=np.where(data["acceleration"]>20,20,data["acceleration"])

# %%
data["acceleration"]=np.where(data["acceleration"]<10,10,data["acceleration"])

# %%
sb.boxplot(x=data["cylinders"],y=data["acceleration"])
# Out:
# <Axes: xlabel='cylinders', ylabel='acceleration'>

# %%
numerical=["mpg","cylinders","displacement","horsepower","weight","acceleration"]

# %%
sb.pairplot(data[numerical],height=2)

# %%
sb.heatmap(data.corr(method="spearman"),annot=True,vmin=-1,vmax=1,center=0,cmap="coolwarm")
# Out:
# C:\Users\DS1\AppData\Local\Temp\ipykernel_2268\3697334940.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sb.heatmap(data.corr(method="spearman"),annot=True,vmin=-1,vmax=1,center=0,cmap="coolwarm")
# <Axes: >
